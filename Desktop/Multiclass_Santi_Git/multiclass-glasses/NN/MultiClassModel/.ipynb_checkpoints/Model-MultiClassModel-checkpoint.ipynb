# %%
import keras
import os
import tensorboard as tb
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers.core import Dense
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten
from keras.models import model_from_json
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import img_to_array
from keras.layers import Dropout
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np
import pandas as pd
import PIL
from PIL import Image
import scipy.io as sio
from keras.utils import to_categorical
import scipy.misc as mi
import matplotlib.pyplot as plt
# Out:
# /home/neuronelab/.local/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# import the necessary packages
import os

def list_images(basePath, contains=None):
    # return the set of files that are valid
    return list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=contains)

def list_files(basePath, validExts=(".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff"), contains=None):
    # loop over the directory structure
    for (rootDir, dirNames, filenames) in os.walk(basePath):
        # loop over the filenames in the current directory
        for filename in filenames:
            # if the contains string is not none and the filename does not contain
            # the supplied string, then ignore the file
            if contains is not None and filename.find(contains) == -1:
                continue

            # determine the file extension of the current file
            ext = filename[filename.rfind("."):].lower()

            # check to see if the file is an image and should be processed
            if ext.endswith(validExts):
                # construct the path to the image and yield it
                imagePath = os.path.join(rootDir, filename).replace(" ", "\\ ")
                yield imagePath

# %%
# Import necessary packages
import argparse

# Import necessary components to build LeNet
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2

def alexnet_model(img_shape=(64, 64, 3), n_classes=17, l2_reg=0.,weights=None):

    # Initialize model
    alexnet = Sequential()

    # Layer 1
    alexnet.add(Conv2D(96, (11, 11), input_shape=img_shape,
        padding='same', kernel_regularizer=l2(l2_reg)))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer 2
    alexnet.add(Conv2D(256, (5, 5), padding='same'))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer 3
    alexnet.add(ZeroPadding2D((1, 1)))
    alexnet.add(Conv2D(512, (3, 3), padding='same'))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer 4
    alexnet.add(ZeroPadding2D((1, 1)))
    alexnet.add(Conv2D(1024, (3, 3), padding='same'))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))

    # Layer 5
    alexnet.add(ZeroPadding2D((1, 1)))
    alexnet.add(Conv2D(1024, (3, 3), padding='same'))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer 6
    alexnet.add(Flatten())
    alexnet.add(Dense(3072))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 7
    alexnet.add(Dense(4096))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('relu'))
    alexnet.add(Dropout(0.5))

    # Layer 8
    alexnet.add(Dense(n_classes))
    alexnet.add(BatchNormalization())
    alexnet.add(Activation('softmax'))

    if weights is not None:
        alexnet.load_weights(weights)

    return alexnet

def parse_args():
    parser = argparse.ArgumentParser(description='AlexNet model')
    optional = parser._action_groups.pop()
    required = parser.add_argument_group('required arguments')
    optional.add_argument('--print_model',
        dest='print_model',
        help='Print AlexNet model',
        action='store_true')
    parser._action_groups.append(optional)
    return parser.parse_args()

# %%
def createModel():
    model = Sequential()
    
    #Convolutional layers with 32 filters / kernels with a window size of 3×3
        
    model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(64,64,3)))
    model.add(Conv2D(32, (3, 3), activation='relu'))
     #Max pooling layer with window size 2×2
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    
    #Conv layer with 64 filters
        
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
 
    model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
 
    #Dense layer which performs the classification among 10 classes using a softmax layer
    
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(17, activation='softmax'))
     
    return model

# %%
import random
import cv2

# %%
seed = 9
np.random.seed(seed)

# %%
import pickle
def savepickle(obj , filename):
    f = open(filename+'.pckl', 'wb')
    pickle.dump(obj, f)
    f.close()
def loadpickle(filename):
    f = open(filename+'.pckl', 'rb')
    obj = pickle.load(f)
    f.close()
    return obj

# %%
imageFolderPath = '/home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes'
# initialize the data and labels
print("[INFO] loading images...")
data = []
labels = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(list_images(imageFolderPath)))
random.seed(42)
random.shuffle(imagePaths)

# loop over the input images
for imagePath in imagePaths:
    if imagePath is not None:
        print(imagePath)
# load the image, pre-process it, and store it in the data list
        try:
            image = cv2.imread(imagePath)
            zimage = cv2.resize(image, (64, 64))
            image = img_to_array(zimage)
            data.append(image)
        # extract the class label from the image path and update the
        # labels list
            label = int(imagePath.split(os.path.sep)[-2][-2:])-1
            print(label)
        #Here we have to change the laveling to make it an integer instead of just 1 and sunglasses, also we have to use
        #sparse_categorical_crossentropy cuz is integers and not one-hot encoded
        
            #label = 1 if label == "Armani" elif 2
            labels.append(label)
        except:
            print("Image with error ", imagePath)

# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)
# Out:
# [INFO] loading images...
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb309.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace155.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada121.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren138.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace137.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada288.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess148.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH231.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren128.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci36.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors55.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci55.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren215.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley263.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH276.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman203.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police342.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry383.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman120.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord89.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca81.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue54.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police364.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police294.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren295.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman66.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace89.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue153.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord3.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman156.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue151.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess77.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman132.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada112.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca332.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue234.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry66.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley79.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord158.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace45.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police118.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman283.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue69.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police218.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman6.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb27.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol420.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman222.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol112.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren196.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol254.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca397.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb436.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors145.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol140.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors331.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess360.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors311.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren286.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue369.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess1.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci248.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci49.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren257.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley276.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH293.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_229.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca219.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley356.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord308.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci141.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess136.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada84.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH50.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley152.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman190.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol7.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry71.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren244.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb427.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb19.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_186.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada65.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada60.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace364.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada64.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren170.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley254.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_273.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca220.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace148.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue202.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol102.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol142.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley93.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue206.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren102.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb317.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess66.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb307.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren52.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol94.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada26.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess315.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue325.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors194.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol519.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci103.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren29.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police85.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess24.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb171.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada271.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue73.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb104.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol48.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren44.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry276.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci258.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_135.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol131.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren275.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman236.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess333.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren36.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci232.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord28.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess62.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue254.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol86.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb251.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry201.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police174.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca252.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors15.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci12.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police225.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley377.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police173.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry304.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb91.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada18.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb42.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb431.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police378.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb252.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace107.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police57.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada3.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord247.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb223.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol310.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH218.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren245.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace108.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley278.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol76.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police160.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry46.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace290.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace104.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord223.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol340.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren85.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess380.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley19.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada363.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca125.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH162.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley319.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb6.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman35.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors11.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH306.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci289.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren6.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada1.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace348.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_52.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca261.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH23.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_181.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors97.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb239.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue272.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors60.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb24.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_54.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police206.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry283.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren237.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord339.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren112.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace156.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord5.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry133.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors159.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue57.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb266.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors8.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police185.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb361.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley65.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord244.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_31.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley358.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue255.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada52.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess378.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley22.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci16.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman119.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess215.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue341.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord295.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace214.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord325.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH28.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley305.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman145.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry108.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol546.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca134.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb382.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord16.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada59.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren28.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb199.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors108.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_191.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley94.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue321.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry109.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors282.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH205.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol105.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess87.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada132.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren168.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police15.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue165.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol5.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren234.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord269.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol196.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci295.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb205.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol73.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH131.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb312.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord233.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci146.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace325.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_244.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca128.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors143.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess212.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police90.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb489.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci177.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry258.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry229.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TomFord14/TomFord258.jpg
# 13
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police209.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH17.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace162.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb405.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada185.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci176.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca150.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley51.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police282.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry289.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Burberry03/Burberry7.jpg
# 2
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada303.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_247.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess180.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada362.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/TommyHilfiger15/TommyH149.jpg
# 14
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Vogue17/Vogue397.jpg
# 16
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman178.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors68.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess7.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada214.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace256.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol350.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol208.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Kors07/Kors210.jpg
# 6
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Gu
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Prada11/Prada238.jpg
# 10
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca99.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Police10/Police322.jpg
# 9
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren213.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca329.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman23.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Persol09/persol533.jpg
# 8
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Carrera04/carreca91.jpg
# 3
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman246.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Oakley08/Oakley262.jpg
# 7
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Boss02/HugoBoss_259.jpg
# 1
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Versace16/Versace120.jpg
# 15
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren66.jpg
# 11
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Ray-Ban13/rb364.jpg
# 12
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Gucci05/Gucci116.jpg
# 4
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Guess06/Guess104.jpg
# 5
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/Armani01/Arman221.jpg
# 0
# /home/neuronelab/Desktop/FraudDetection_v2/NN/MultiClassModel/classes/RalphLauren12/RalphLauren17.jpg
# 11

# %%
labels=labels.astype(int)

# %%
labels.shape
# Out:
# (5516,)

# %%
(trainX, testX, trainY, testY) = train_test_split(data,labels, test_size=0.20, random_state=42)

# convert the labels from integers to vectors
trainY = to_categorical(trainY, num_classes=17)
testY = to_categorical(testY, num_classes=17)
print(trainY.shape)
# Out:
# (4412, 17)

# %%
model=createModel()

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(trainX, trainY, validation_data=(testX, testY),shuffle=True, epochs=100, batch_size=32, verbose=1)
# Out:
# Train on 4412 samples, validate on 1104 samples
# Epoch 1/100
# 4412/4412 [==============================] - 3s 708us/step - loss: 2.8310 - acc: 0.0859 - val_loss: 2.8277 - val_acc: 0.0879
# Epoch 2/100
# 4412/4412 [==============================] - 2s 551us/step - loss: 2.8264 - acc: 0.0893 - val_loss: 2.8249 - val_acc: 0.0879
# Epoch 3/100
# 4412/4412 [==============================] - 2s 538us/step - loss: 2.8273 - acc: 0.0893 - val_loss: 2.8213 - val_acc: 0.0879
# Epoch 4/100
# 4412/4412 [==============================] - 2s 536us/step - loss: 2.8218 - acc: 0.0884 - val_loss: 2.8149 - val_acc: 0.0861
# Epoch 5/100
# 4412/4412 [==============================] - 2s 548us/step - loss: 2.8059 - acc: 0.0913 - val_loss: 2.7999 - val_acc: 0.0851
# Epoch 6/100
# 4412/4412 [==============================] - 2s 544us/step - loss: 2.7959 - acc: 0.0895 - val_loss: 2.7916 - val_acc: 0.0879
# Epoch 7/100
# 4412/4412 [==============================] - 2s 553us/step - loss: 2.7874 - acc: 0.0922 - val_loss: 2.7839 - val_acc: 0.0870
# Epoch 8/100
# 4412/4412 [==============================] - 2s 550us/step - loss: 2.7666 - acc: 0.0972 - val_loss: 2.7700 - val_acc: 0.1132
# Epoch 9/100
# 4412/4412 [==============================] - 2s 546us/step - loss: 2.7291 - acc: 0.1147 - val_loss: 2.7925 - val_acc: 0.0969
# Epoch 10/100
# 4412/4412 [==============================] - 2s 544us/step - loss: 2.7139 - acc: 0.1308 - val_loss: 2.7074 - val_acc: 0.1268
# Epoch 11/100
# 4412/4412 [==============================] - 2s 546us/step - loss: 2.6542 - acc: 0.1582 - val_loss: 2.6842 - val_acc: 0.1359
# Epoch 12/100
# 4412/4412 [==============================] - 2s 550us/step - loss: 2.5826 - acc: 0.1772 - val_loss: 2.6425 - val_acc: 0.1630
# Epoch 13/100
# 4412/4412 [==============================] - 2s 551us/step - loss: 2.5109 - acc: 0.1997 - val_loss: 2.5810 - val_acc: 0.1830
# Epoch 14/100
# 4412/4412 [==============================] - 2s 546us/step - loss: 2.4305 - acc: 0.2196 - val_loss: 2.5779 - val_acc: 0.1957
# Epoch 15/100
# 4412/4412 [==============================] - 2s 549us/step - loss:
100
# 4412/4412 [==============================] - 2s 546us/step - loss: 0.2704 - acc: 0.9170 - val_loss: 4.4063 - val_acc: 0.2437
# Epoch 87/100
# 4412/4412 [==============================] - 2s 540us/step - loss: 0.2717 - acc: 0.9152 - val_loss: 4.5059 - val_acc: 0.2464
# Epoch 88/100
# 4412/4412 [==============================] - 2s 528us/step - loss: 0.2625 - acc: 0.9173 - val_loss: 4.4220 - val_acc: 0.2400
# Epoch 89/100
# 4412/4412 [==============================] - 2s 533us/step - loss: 0.2542 - acc: 0.9152 - val_loss: 4.4127 - val_acc: 0.2400
# Epoch 90/100
# 4412/4412 [==============================] - 2s 524us/step - loss: 0.2478 - acc: 0.9193 - val_loss: 4.7727 - val_acc: 0.2364
# Epoch 91/100
# 4412/4412 [==============================] - 2s 527us/step - loss: 0.2860 - acc: 0.9121 - val_loss: 4.4211 - val_acc: 0.2455
# Epoch 92/100
# 4412/4412 [==============================] - 2s 544us/step - loss: 0.2774 - acc: 0.9134 - val_loss: 4.3405 - val_acc: 0.2373
# Epoch 93/100
# 4412/4412 [==============================] - 2s 543us/step - loss: 0.3061 - acc: 0.9041 - val_loss: 4.2568 - val_acc: 0.2536
# Epoch 94/100
# 4412/4412 [==============================] - 2s 544us/step - loss: 0.2581 - acc: 0.9195 - val_loss: 4.4081 - val_acc: 0.2536
# Epoch 95/100
# 4412/4412 [==============================] - 2s 531us/step - loss: 0.2814 - acc: 0.9078 - val_loss: 4.3275 - val_acc: 0.2491
# Epoch 96/100
# 4412/4412 [==============================] - 2s 535us/step - loss: 0.2737 - acc: 0.9141 - val_loss: 4.3560 - val_acc: 0.2609
# Epoch 97/100
# 4412/4412 [==============================] - 2s 534us/step - loss: 0.2715 - acc: 0.9168 - val_loss: 4.4490 - val_acc: 0.2428
# Epoch 98/100
# 4412/4412 [==============================] - 2s 529us/step - loss: 0.2747 - acc: 0.9109 - val_loss: 4.6188 - val_acc: 0.2482
# Epoch 99/100
# 4412/4412 [==============================] - 2s 532us/step - loss: 0.2520 - acc: 0.9141 - val_loss: 4.4806 - val_acc: 0.2391
# Epoch 100/100
# 4412/4412 [==============================] - 2s 546us/step - loss: 0.2548 - acc: 0.9191 - val_loss: 4.4710 - val_acc: 0.2509

# %%
hist = model.history
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-4ddcd3d34d82> in <module>()
# ----> 1 hist = model.history
#
# AttributeError: 'Sequential' object has no attribute 'history'

# %%
# summarize history for accuracy
plt.plot(hist.history['acc'])
plt.plot(hist.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# pre-process the image for classification
image = cv2.imread('test/r1.jpg')### CHANGE PATH
zimage = cv2.resize(image, (64, 64))
image = zimage.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)
#IMAGE LEGEND R = RAYBAN  , S=SUNGLASSES , W = PEOPLE WITH SUNGLASSES , N = NO SUNGLASSES

# %%
def preprocessInpuutImage(pathToImage, width , height):
    image = cv2.imread(pathToImage)### CHANGE PATH
    zimage = cv2.resize(image, (width, height))
    image = zimage.astype("float") / 255.0
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    
    return image

# %%
pred = model.predict(preprocessInpuutImage('/home/neuronelab/Desktop/FraudDetection_v2/NN/test_images/s2.jpg' , 64 , 64))[0]
print(pred.max() , pred.argmax())
print(pred)
# Out:
# (0.91275704, 15)
# [7.1100367e-05 4.1538621e-03 2.4893286e-03 6.1389891e-04 2.9704009e-07
#  2.8146025e-07 8.7255882e-03 1.5109383e-05 1.7625499e-03 9.1324797e-09
#  3.2666544e-06 4.3527070e-05 2.6074983e-04 3.2241738e-03 1.1315717e-06
#  9.1275704e-01 6.5878019e-02]

# %%
pred[3]
# Out:
# 0.0006138989

# %%
model.save('multiClass64x64.model')

# %%
(notSunglasses, sunglasses) = model.predict(preprocessInpuutImage('test/s1.jpg' , 64 , 64))[0]
# build the label
label = "Sunglasses" if sunglasses > notSunglasses else "Not Sunglasses"
proba = sunglasses if sunglasses > notSunglasses else notSunglasses
label = "{}: {:.2f}%".format(label, proba * 100)
print(label)

# %%
from keras import models
layer_outputs = [layer.output for layer in model.layers[:8]]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)

# %%
activations = activation_model.predict(image)
first_layer_activation = activations[4]
plt.matshow(first_layer_activation[0, :, :, 4], cmap='viridis')

# %%
layer_names = []
for layer in model.layers[:8]:
    layer_names.append(layer.name)
images_per_row = 16
for layer_name, layer_activation in zip(layer_names, activations):
    n_features = layer_activation.shape[-1]
    size = layer_activation.shape[1]
    n_cols = n_features // images_per_row
    display_grid = np.zeros((size * n_cols, images_per_row * size))
    for col in range(n_cols):
        for row in range(images_per_row):
            channel_image = layer_activation[0,
            :, :,
            col * images_per_row + row]
            channel_image -= channel_image.mean()
            channel_image /= channel_image.std()
            channel_image *= 64
            channel_image += 128
            channel_image = np.clip(channel_image, 0, 255).astype('uint8')
            display_grid[col * size : (col + 1) * size,
            row * size : (row + 1) * size] = channel_image
    scale = 1. / size
    plt.figure(figsize=(scale * display_grid.shape[1],
    scale * display_grid.shape[0]))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')

# %%
second = createModel()

# %%
second.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
imageFolderPath = '/Users/michelecipriano/Desktop/images_2/'
# initialize the data and labels
print("[INFO] loading images...")
data2 = []
labels2 = []

# grab the image paths and randomly shuffle them
imagePaths = sorted(list(paths.list_images(imageFolderPath)))
random.seed(42)
random.shuffle(imagePaths)

# loop over the input images
for imagePath in imagePaths:
    if imagePath is not None:
        print(imagePath)
# load the image, pre-process it, and store it in the data list
        image = cv2.imread(imagePath)
        zimage = cv2.resize(image, (128, 128))
        image = img_to_array(zimage)
        data2.append(image)
        # extract the class label from the image path and update the
        # labels list
        label = imagePath.split(os.path.sep)[-2]
        print(label)
        label = 1 if label == "rayban" else 0
        labels2.append(label)

# scale the raw pixel intensities to the range [0, 1]
data2 = np.array(data2, dtype="float") / 255.0
labels2 = np.array(labels2)

# %%
(trainX, testX, trainY, testY) = train_test_split(data2,labels2, test_size=0.20, random_state=42)

# convert the labels from integers to vectors
trainY = to_categorical(trainY, num_classes=2)
testY = to_categorical(testY, num_classes=2)
print(trainX.shape)

# %%
second.fit(trainX, trainY, validation_data=(testX, testY),shuffle=True, epochs=5, batch_size=32, verbose=1)

# %%
# pre-process the image for classification
image = cv2.imread('test/r2.jpg')### CHANGE PATH
zimage = cv2.resize(image, (128, 128))
image = zimage.astype("float") / 255.0
image = img_to_array(image)
image = np.expand_dims(image, axis=0)
#IMAGE LEGEND R = RAYBAN  , S=SUNGLASSES , W = PEOPLE WITH SUNGLASSES , N = NO SUNGLASSES
(notSunglasses, sunglasses) = second.predict(image)[0]
# build the label
label = "RayBan" if sunglasses > notSunglasses else "Not Rayban"
proba = sunglasses if sunglasses > notSunglasses else notSunglasses
label = "{}: {:.2f}%".format(label, proba * 100)
print(label)

# %%
#https://flyyufelix.github.io/2016/10/03/fine-tuning-in-keras-part1.html
