# %% [markdown]
# This code is for managing the API result
#
# Set the environment variable GOOGLE_APPLICATION_CREDENTIALS to the file path of the JSON file that contains your service account key.

# %% [raw]
# import io
# import os
#
# # Imports the Google Cloud client library
# from google.cloud import vision
# from google.cloud.vision import types
#
# # Instantiates a client
# client = vision.ImageAnnotatorClient()
#
# # The name of the image file to annotate
# file_name = 'C:/Users/ADMIIN/Desktop/qua.jpg'
#
#
# # Loads the image into memory
# with io.open(file_name, 'rb') as image_file:
#     content = image_file.read()
#
# image = types.Image(content=content)
#
# # Performs label detection on the image file
# response = client.web_detection(image, max_results=None, retry=None, timeout=None)
# labels = response.web_detection
#
# print('Labels:')
# for label in labels:
#     print(label.description)

# %%
import argparse
import io
import re

from google.cloud import storage
from google.cloud import vision
from google.protobuf import json_format

# %%
# [START vision_web_detection]
def detect_web(path):
    """Detects web annotations given an image."""
    client = vision.ImageAnnotatorClient()

    # [START vision_python_migration_web_detection]
    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.web_detection(image=image)
    annotations = response.web_detection
    print(type(annotations))
    if annotations.best_guess_labels:
        for label in annotations.best_guess_labels:
            print('\nBest guess label: {}'.format(label.label))

    if annotations.pages_with_matching_images:
        print('\n{} Pages with matching images found:'.format(
            len(annotations.pages_with_matching_images)))

        for page in annotations.pages_with_matching_images:
            print('\n\tPage url   : {}'.format(page.url))

            if page.full_matching_images:
                print('\t{} Full Matches found: '.format(
                       len(page.full_matching_images)))

                for image in page.full_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

            if page.partial_matching_images:
                print('\t{} Partial Matches found: '.format(
                       len(page.partial_matching_images)))

                for image in page.partial_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

    if annotations.web_entities:
        print('\n{} Web entities found: '.format(
            len(annotations.web_entities)))

        for entity in annotations.web_entities:
            print('\n\tScore      : {}'.format(entity.score))
            print(u'\tDescription: {}'.format(entity.description))

    if annotations.visually_similar_images:
        print('\n{} visually similar images found:\n'.format(
            len(annotations.visually_similar_images)))

        for image in annotations.visually_similar_images:
            print('\tImage url    : {}'.format(image.url))
            
    return annotations
    # [END vision_python_migration_web_detection]
# [END vision_web_detection]

# %%
def localize_objects(path):
    """Localize objects in the local image.

    Args:
    path: The path to the local file.
    """
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()

    with open(path, 'rb') as image_file:
        content = image_file.read()
    image = vision.types.Image(content=content)

    objects = client.object_localization(
        image=image).localized_object_annotations

    print('Number of objects found: {}'.format(len(objects)))
    objs = dict()
    for object_ in objects:
        print('\n{} (confidence: {})'.format(object_.name, object_.score))
        print('Normalized bounding polygon vertices: ')
        objs[object_.name] = object_.score
        for vertex in object_.bounding_poly.normalized_vertices:
            print(' - ({}, {})'.format(vertex.x, vertex.y))
    return objs

# %%
def detect_labels(path):
    """Detects labels in the file."""
    from google.cloud import vision
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.types.Image(content=content)

    response = client.label_detection(image=image)
    labels = response.label_annotations
    print('Labels:')
    descriptions = dict()
    for label in labels:
        print(label.description)
        descriptions[label.description]=label.score
    return descriptions

# %%
labels = detect_labels('C:/Users/ADMIIN/Desktop/FraudDetection_v21/NN/test_images/r1.jpg')
obj = localize_objects('C:/Users/ADMIIN/Desktop/FraudDetection_v21/NN/test_images/r1.jpg')
web = detect_web('C:/Users/ADMIIN/Desktop/FraudDetection_v21/NN/test_images/r1.jpg')
# Out:
# Labels:
# eyewear
# sunglasses
# vision care
# glasses
# product
# product
# goggles
# font
# Number of objects found: 1
#
# Sunglasses (confidence: 0.9139588475227356)
# Normalized bounding polygon vertices:
#  - (0.04180198535323143, 0.3081950843334198)
#  - (0.6781980395317078, 0.3081950843334198)
#  - (0.6781980395317078, 0.7190989851951599)
#  - (0.04180198535323143, 0.7190989851951599)

# %%
import operator
max(labels.items(), key=operator.itemgetter(1))[0]
# Out:
# 'eyewear'

# %%
obj
# Out:
# {'Sunglasses': 0.9139588475227356}

# %%
"""annotations.best_guess_labels:
        #for label in annotations.best_guess_labels:
            print('\nBest guess label: {}'.format(label.label))

    if annotations.pages_with_matching_images:
        for page in annotations.pages_with_matching_images:
            print(.format(page.url))

            if page.full_matching_images:
                print('\t{} Full Matches found: '.format(
                       len(page.full_matching_images)))

                for image in page.full_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

            if page.partial_matching_images:
                print('\t{} Partial Matches found: '.format(
                       len(page.partial_matching_images)))

                for image in page.partial_matching_images:
                    print('\t\tImage url  : {}'.format(image.url))

    if annotations.web_entities:
        print('\n{} Web entities found: '.format(
            len(annotations.web_entities)))

        for entity in annotations.web_entities:
            print('\n\tScore      : {}'.format(entity.score))
            print(u'\tDescription: {}'.format(entity.description))

    if annotations.visually_similar_images:
        print('\n{} visually similar images found:\n'.format(
            len(annotations.visually_similar_images)))

        for image in annotations.visually_similar_images:
            print('\tImage url    : {}'.format(image.url))
            """
web
# Out:
# web_entities {
#   entity_id: "/g/11dxcp3fzp"
#   score: 0.8313999772071838
#   description: "Ray-Ban Round Double Bridge"
# }
# web_entities {
#   entity_id: "/m/02m7zw"
#   score: 0.7394999861717224
#   description: "Ray-Ban"
# }
# web_entities {
#   entity_id: "/t/21bbnhtdrdx0"
#   score: 0.7394999861717224
# }
# web_entities {
#   entity_id: "/g/11cpg1np0k"
#   score: 0.7276999950408936
#   description: "Ray-Ban Round Metal"
# }
# web_entities {
#   entity_id: "/g/11c2nxmcsh"
#   score: 0.7071999907493591
#   description: "Ray-Ban Aviator Flash"
# }
# web_entities {
#   entity_id: "/g/11c5hlclxs"
#   score: 0.7026000022888184
#   description: "Ray-Ban Aviator Classic"
# }
# web_entities {
#   entity_id: "/m/017ftj"
#   score: 0.701200008392334
#   description: "Sunglasses"
# }
# web_entities {
#   entity_id: "/g/11g8ksb0p3"
#   score: 0.7002000212669373
#   description: "Ray-Ban Blaze Round"
# }
# web_entities {
#   entity_id: "/g/11d_7ptj_k"
#   score: 0.6772000193595886
#   description: "Ray-Ban Blaze Clubmaster"
# }
# web_entities {
#   entity_id: "/g/11cs24zpsz"
#   score: 0.6161999702453613
#   description: "Ray-Ban Double Bridge"
# }
# full_matching_images {
#   url: "https://images.rewardstyle.com/img?v=2.13&p=n_93407837&max&height=0&width=680"
# }
# full_matching_images {
#   url: "https://cdn3.volusion.com/dgz39.etzj9/v/vspfiles/photos/RB3647N-001-2.jpg?1535114704"
# }
# full_matching_images {
#   url: "https://1.bp.blogspot.com/-7xd497-p0U8/WLtvGLOmIVI/AAAAAAAAFTA/fHtKuNXigjYkzNqHHtCREPc9_aYzdpwkwCLcB/s1600/rb%2B2.jpg"
# }
# full_matching_images {
#   url: "https://stat.ameba.jp/user_images/20170511/15/odd-kumamoto/da/d5/j/o0594038513934828338.jpg?caw=800"
# }
# full_matching_images {
#   url: "https://www.dropouthollywood.com/images/sunglasses/ray%20ban-891zuc.jpg"
# }
# full_matching_images {
#   url: "http://www.iltempoarte.it/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/r/a/rayban_3647-583eqx.jpg"
# }
# full_matching_images {
#   url: "https://d26lpennugtm8s.cloudfront.net/stores/632/163/products/ddd11-f5ed1d577440b3055a15255356457858-640-0.jpg"
# }
# full_matching_images {
#   url: "https://www.hotsale.com.ar/public/uploads/megaofertas/307/ddd-5aedba0163aa4.jpg"
# }
# full_matching_images {
#   url: "http://ochkiok.ru/assets/images/sunglasess/Vogue/img_art_VO_4082S_BY_GIGI_HADID_280_87.jpg"
# }
# full_matching_images {
#   url: "http://highclass.com.ua/image/cache/catalog/2017/%20SUNGLASSES/Vogue/woman/VO%204082S%20BY%20GIGI%20HADID/highclass_VO_4082S_BY_GIGI_HADID_280_87-500x220.jpg"
# }
# partial_matching_images {
#   url: "https://assets.ray-ban.com/is/image/RayBan/8053672737622_shad_qt?id=lEcqB0&wid=2000&hei=1500&fmt=jpg"
# }
# partial_matching_images {
#   url: "https://pbs.twimg.com/media/DdivKegUQAA4J8H.jpg:large"
# }
# partial_matching_images {
#   url: "https://cdnc.lystit.com/photos/stand-out/7b60fcf2/ray-ban-black-Blackgold-Round-Double-Bridge-Metal-Sunglasses.jpeg"
# }
# partial_matching_images {
#   url: "https://imaxxe.com/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/s/c/screen_shot_2018-06-16_at_10.32.49_pm.png"
# }
# partial_matching_images {
#   url: "https://scontent-atl3-1.cdninstagram.com/vp/c268823293d67bdb79e217145deb013b/5C53B6F9/t51.2885-15/fr/e15/s1080x1080/40384335_1147055838775488_1478811824975862021_n.jpg"
# }
# partial_matching_images {
#   url: "https://scontent-sea1-1.cdninstagram.com/vp/37972ac0aa192bea4b6fa61c2fad9635/5C56B46E/t51.2885-15/e35/42409712_271299350181652_1628511923581608185_n.jpg?se=7&ig_cache_key=MTg4MDcxODUxMDIxMDIxMzQwMg%3D%3D.2"
# }
# partial_matching_images {
#   url: "https://www.miamimerchandisemart.com/wp-content/uploads/2017/07/ray-ban-round-double-bridge-rb3647n-001-gold-green-classic-g-15-sunglasses-412305_890.jpg"
# }
# partial_matching_images {
#   url: "https://v0.static.betalabs.com.br/uploads/gestao_ja/produto/produto_foto/thumb/1000x10000460c7e89e331c8ea7927b734d554e31.jpg"
# }
# partial_matching_images {
#   url: "https://www.sunglasses2u.com/library/images/originals/14/_3D.3_24P_2C31_3F_2C34S_2CC_24S-C_3CS-34X_3C3_24P.7_2CT_2C_23_60X_3CC0_60_0A_60_0A.jpg"
# }
# partial_matching_images {
#   url: "https://http2.mlstatic.com/ray-ban-rb3647n-001-round-double-bridge-negro-g-15-dorado-D_NQ_NP_698881-MLM27723668097_072018-F.jpg"
# }
# pages_with_matching_images {
#   url: "https://www.ray-ban.com/usa/sunglasses/RB3647N%20UNISEX%20004-round%20double%20bridge-gold/8053672737639"
#   page_title: "<b>Ray</b>-<b>Ban</b> Round Double Bridge RB3647N Gold - Metal - Copper ..."
#   full_matching_images {
#     url: "https://assets.ray-ban.com/is/image/RayBan/8053672737622_shad_qt?$594$"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.ray-ban.com/usa/sunglasses/RB3647N%20UNISEX%20005-round%20double%20bridge-gold/8053672737646"
#   page_title: "<b>Ray</b>-<b>Ban</b> Round Double Bridge RB3647N Gold - Metal - Silver ..."
#   full_matching_images {
#     url: "https://assets.ray-ban.com/is/image/RayBan/8053672737622_shad_qt?$594$"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.ray-ban.com/usa/sunglasses/RB3647N%20UNISEX%20007-round%20double%20bridge-black/8053672737615"
#   page_title: "<b>Ray</b>-<b>Ban</b> Round Double Bridge RB3647N Black - Metal - Blue/Gray ..."
#   full_matching_images {
#     url: "https://assets.ray-ban.com/is/image/RayBan/8053672737622_shad_qt?$594$"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.ray-ban.com/usa/sunglasses/RB3647N%20UNISEX%20002-round%20double%20bridge-gold/8053672742299"
#   page_title: "<b>Ray</b>-<b>Ban</b> Round Double Bridge RB3647N Gold - Metal - Blue ..."
#   full_matching_images {
#     url: "https://assets.ray-ban.com/is/image/RayBan/8053672737622_shad_qt?$594$"
#   }
# }
# pages_with_matching_images {
#   url: "https://jackssurfboards.com/collections/ray-ban"
#   page_title: "<b>Ray</b>-<b>Ban</b> \342\200\223 Jack&#39;s Surfboards"
#   partial_matching_images {
#     url: "https://cdn.shopify.com/s/files/1/2489/2950/products/8053672737622_shad_1_800x900.jpg?v=1534185687"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.mileageplusawards.com/ray-ban"
#   page_title: "MileagePlus Merchandise Awards. <b>Ray</b>-<b>Ban</b>"
#   partial_matching_images {
#     url: "https://s3.us-east-2.amazonaws.com/merchawards/images/thumbs/0015514_415.jpeg"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.gumtree.com.au/s-accessories/ray+ban+round/k0c18575"
#   page_title: "<b>ray ban</b> round | Accessories | Gumtree Australia Free Local Classifieds"
#   partial_matching_images {
#     url: "https://i.ebayimg.com/00/s/MTMzNFg3NTA=/z/y3sAAOSwb-Rbv-aL/$_35.JPG"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.gumtree.com.au/s-accessories/rayban+round/k0c18575"
#   page_title: "<b>rayban</b> round | Accessories | Gumtree Australia Free Local Classifieds"
#   partial_matching_images {
#     url: "https://i.ebayimg.com/00/s/MTMzNFg3NTA=/z/y3sAAOSwb-Rbv-aL/$_35.JPG"
#   }
# }
# pages_with_matching_images {
#   url: "https://jrssurfandski.com.au/brands/ray-ban.html"
#   page_title: "<b>Ray Ban</b> - Brands | JR&#39;s Surf &amp; Ski - Adelaide&#39;s Surf, Snow, Skate ..."
#   partial_matching_images {
#     url: "https://jrssurfandski.com.au/media/catalog/product/cache/1/small_image/245x/9df78eab33525d08d6e5fb8d27136e95/s/c/screen_shot_2017-03-07_at_11.36.36_am.png"
#   }
# }
# pages_with_matching_images {
#   url: "https://www.gumtree.com.au/s-ray+ban+sunglasses+gold/k0"
#   page_title: "<b>ray ban</b> sunglasses gold | Gumtree Australia Free Local Classifieds"
#   partial_matching_images {
#     url: "https://i.ebayimg.com/00/s/MTMzNFg3NTA=/z/y3sAAOSwb-Rbv-aL/$_35.JPG"
#   }
# }
# visually_similar_images {
#   url: "https://www.sunglasses-direct.co.uk/wp-content/uploads/2017/03/RB3647N-00258.jpg"
# }
# visually_similar_images {
#   url: "https://process.fs.grailed.com/AJdAgnqCST4iPtnUxiGtTz/cache=expiry:max/rotate=deg:exif/resize=width:1100,fit:crop/output=format:jpg,quality:70/compress/BE5Ox9DVQyKpCIoQe1GK"
# }
# visually_similar_images {
#   url: "https://www.shadestation.co.uk/media/thumbs/920x575/media/luximages/0RB3647N__001_330Afw920fh575.png"
# }
# visually_similar_images {
#   url: "http://www.ludotecadivervalles.es/images/category_13/Gafas%20de%20sol%20Ray%20Ban%20RB3647N%20REF%20135141193%20tienda%20outlet%20en%20l%C3%ADnea.jpg?lightbox[autoresize]=false"
# }
# visually_similar_images {
#   url: "https://assets.ray-ban.com/is/image/RayBan/8053672737615_shad_qt?$594$"
# }
# visually_similar_images {
#   url: "https://perfecteyes2020.com/image/cache/633000/633905/cmsimageoR16Qb-363x247.jpg"
# }
# visually_similar_images {
#   url: "https://www.picclickimg.com/d/l400/pict/183445742777_/Ray-Ban-RB3647-N-001-Gold-Metal-Tortoise-Green-Lens.jpg"
# }
# visually_similar_images {
#   url: "https://www.brille-kaulard.de/media/image/thumbnail/84079_990x577.jpg"
# }
# best_guess_labels {
#   label: "ray ban rb3647"
#   language_code: "en"
# }
