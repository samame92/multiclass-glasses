# %%
# import the necessary packages
from imutils import paths
import argparse
import requests
import cv2
import os

# %%
urls = 'C:/Users/ADMIIN/Downloads/urls (4).txt'
# grab the list of URLs from the input file, then initialize the
# total number of images downloaded thus far
rows = open(urls).read().strip().split("\n")
print (len(rows))
# Out:
# 631

# %%
import requests
i=1
for url in rows:
    try:
        img_data = requests.get(url).content
        with open('rb' + str(i)+'.jpg', 'wb') as handler:
            handler.write(img_data)
            print(i , 'saved')
            i=i+1
    except:
        print(' #NOT ',i)
        i=i+1
# Out:
# 1 saved
# 2 saved
# 3 saved
# 4 saved
# 5 saved
# 6 saved
# 7 saved
# 8 saved
# 9 saved
# 10 saved
# 11 saved
# 12 saved
# 13 saved
# 14 saved
# 15 saved
# 16 saved
# 17 saved
# 18 saved
# 19 saved
# 20 saved
# 21 saved
# 22 saved
# 23 saved
# 24 saved
# 25 saved
# 26 saved
# 27 saved
# 28 saved
#  #NOT  29
# 30 saved
# 31 saved
# 32 saved
# 33 saved
# 34 saved
# 35 saved
# 36 saved
# 37 saved
# 38 saved
# 39 saved
# 40 saved
# 41 saved
# 42 saved
# 43 saved
# 44 saved
# 45 saved
# 46 saved
# 47 saved
# 48 saved
# 49 saved
# 50 saved
# 51 saved
# 52 saved
# 53 saved
# 54 saved
# 55 saved
# 56 saved
# 57 saved
# 58 saved
# 59 saved
# 60 saved
# 61 saved
# 62 saved
# 63 saved
# 64 saved
# 65 saved
# 66 saved
# 67 saved
# 68 saved
# 69 saved
# 70 saved
# 71 saved
# 72 saved
# 73 saved
# 74 saved
# 75 saved
# 76 saved
# 77 saved
# 78 saved
# 79 saved
# 80 saved
# 81 saved
# 82 saved
# 83 saved
# 84 saved
# 85 saved
# 86 saved
# 87 saved
# 88 saved
# 89 saved
# 90 saved
# 91 saved
# 92 saved
# 93 saved
# 94 saved
# 95 saved
# 96 saved
# 97 saved
# 98 saved
# 99 saved
# 100 saved
# 101 saved
# 102 saved
# 103 saved
# 104 saved
# 105 saved
# 106 saved
# 107 saved
# 108 saved
# 109 saved
# 110 saved
# 111 saved
# 112 saved
# 113 saved
# 114 saved
# 115 saved
# 116 saved
# 117 saved
# 118 saved
# 119 saved
# 120 saved
# 121 saved
# 122 saved
# 123 saved
# 124 saved
# 125 saved
# 126 saved
# 127 saved
# 128 saved
# 129 saved
# 130 saved
# 131 saved
# 132 saved
# 133 saved
# 134 saved
# 135 saved
# 136 saved
# 137 saved
# 138 saved
# 139 saved
# 140 saved
# 141 saved
# 142 saved
# 143 saved
# 144 saved
# 145 saved
# 146 saved
# 147 saved
# 148 saved
# 149 saved
# 150 saved
# 151 saved
# 152 saved
# 153 saved
# 154 saved
# 155 saved
# 156 saved
# 157 saved
# 158 saved
# 159 saved
# 160 saved
# 161 saved
# 162 saved
# 163 saved
# 164 saved
# 165 saved
# 166 saved
# 167 saved
# 168 saved
# 169 saved
# 170 saved
# 171 saved
# 172 saved
# 173 saved
# 174 saved
# 175 saved
# 176 saved
# 177 saved
# 178 saved
# 179 saved
# 180 saved
# 181 saved
# 182 saved
# 183 saved
# 184 saved
# 185 saved
# 186 saved
# 187 saved
# 188 saved
# 189 saved
# 190 saved
# 191 saved
# 192 saved
# 193 saved
# 194 saved
# 195 saved
# 196 saved
# 197 saved
# 198 saved
# 199 saved
# 200 saved
# 201 saved
# 202 saved
# 203 saved
# 204 saved
# 205 saved
# 206 saved
# 207 saved
# 208 saved
# 209 saved
# 210 saved
# 211 saved
# 212 saved
# 213 saved
# 214 saved
# 215 saved
# 216 saved
# 217 saved
# 218 saved
# 219 saved
# 220 saved
# 221 saved
# 222 saved
# 223 saved
# 224 saved
# 225 saved
# 226 saved
# 227 saved
# 228 saved
# 229 saved
# 230 saved
# 231 saved
# 232 saved
# 233 saved
# 234 saved
# 235 saved
# 236 saved
# 237 saved
# 238 saved
# 239 saved
# 240 saved
# 241 saved
# 242 saved
# 243 saved
# 244 saved
# 245 saved
# 246 saved
# 247 saved
# 248 saved
# 249 saved
# 250 saved
# 251 saved
# 252 saved
# 253 saved
# 254 saved
# 255 saved
# 256 saved
# 257 saved
# 258 saved
# 259 saved
# 260 saved
# 261 saved
# 262 saved
# 263 saved
# 264 saved
# 265 saved
# 266 saved
# 267 saved
# 268 saved
# 269 saved
# 270 saved
# 271 saved
# 272 saved
# 273 saved
# 274 saved
# 275 saved
# 276 saved
# 277 saved
# 278 saved
# 279 saved
# 280 saved
# 281 saved
# 282 saved
# 283 saved
# 284 saved
# 285 saved
# 286 saved
# 287 saved
# 288 saved
# 289 saved
# 290 saved
# 291 saved
# 292 saved
# 293 saved
# 294 saved
# 295 saved
# 296 saved
# 297 saved
# 298 saved
# 299 saved
# 300 saved
# 301 saved
# 302 saved
# 303 saved
# 304 saved
# 305 saved
# 306 saved
# 307 saved
# 308 saved
# 309 saved
# 310 saved
# 311 saved
# 312 saved
# 313 saved
# 314 saved
# 315 saved
# 316 saved
# 317 saved
# 318 saved
# 319 saved
# 320 saved
# 321 saved
# 322 saved
# 323 saved
# 324 saved
# 325 saved
# 326 saved
# 327 saved
#  #NOT  328
# 329 saved
# 330 saved
# 331 saved
# 332 saved
# 333 saved
# 334 saved
# 335 saved
# 336 saved
# 337 saved
# 338 saved
# 339 saved
# 340 saved
# 341 saved
# 342 saved
# 343 saved
# 344 saved
# 345 saved
# 346 saved
# 347 saved
# 348 saved
# 349 saved
# 350 saved
# 351 saved
# 352 saved
# 353 saved
# 354 saved
# 355 saved
# 356 saved
# 357 saved
# 358 saved
# 359 saved
# 360 saved
# 361 saved
# 362 saved
# 363 saved
# 364 saved
# 365 saved
# 366 saved
# 367 saved
# 368 saved
# 369 saved
# 370 saved
# 371 saved
# 372 saved
# 373 saved
# 374 saved
# 375 saved
#  #NOT  376
# 377 saved
# 378 saved
# 379 saved
# 380 saved
# 381 saved
# 382 saved
# 383 saved
# 384 saved
# 385 saved
# 386 saved
# 387 saved
# 388 saved
# 389 saved
# 390 saved
# 391 saved
# 392 saved
# 393 saved
# 394 saved
# 395 saved
# 396 saved
# 397 saved
# 398 saved
# 399 saved
# 400 saved
# 401 saved
# 402 saved
# 403 saved
# 404 saved
# 405 saved
# 406 saved
# 407 saved
# 408 saved
# 409 saved
# 410 saved
# 411 saved
# 412 saved
# 413 saved
# 414 saved
# 415 saved
# 416 saved
# 417 saved
# 418 saved
# 419 saved
# 420 saved
# 421 saved
# 422 saved
# 423 saved
# 424 saved
# 425 saved
# 426 saved
# 427 saved
# 428 saved
# 429 saved
# 430 saved
# 431 saved
# 432 saved
# 433 saved
# 434 saved
# 435 saved
# 436 saved
# 437 saved
# 438 saved
# 439 saved
# 440 saved
# 441 saved
# 442 saved
# 443 saved
# 444 saved
# 445 saved
# 446 saved
# 447 saved
# 448 saved
# 449 saved
# 450 saved
# 451 saved
# 452 saved
# 453 saved
# 454 saved
# 455 saved
# 456 saved
# 457 saved
# 458 saved
# 459 saved
# 460 saved
# 461 saved
# 462 saved
# 463 saved
# 464 saved
# 465 saved
# 466 saved
# 467 saved
# 468 saved
# 469 saved
# 470 saved
# 471 saved
# 472 saved
# 473 saved
# 474 saved
# 475 saved
# 476 saved
# 477 saved
# 478 saved
# 479 saved
# 480 saved
# 481 saved
#  #NOT  482
# 483 saved
# 484 saved
# 485 saved
# 486 saved
# 487 saved
# 488 saved
# 489 saved
# 490 saved
# 491 saved
# 492 saved
# 493 saved
# 494 saved
# 495 saved
# 496 saved
# 497 saved
# 498 saved
# 499 saved
# 500 saved
# 501 saved
# 502 saved
# 503 saved
# 504 saved
# 505 saved
# 506 saved
# 507 saved
# 508 saved
# 509 saved
# 510 saved
# 511 saved
# 512 saved
# 513 saved
# 514 saved
# 515 saved
# 516 saved
# 517 saved
# 518 saved
# 519 saved
# 520 saved
# 521 saved
# 522 saved
# 523 saved
# 524 saved
# 525 saved
# 526 saved
# 527 saved
# 528 saved
# 529 saved
# 530 saved
# 531 saved
# 532 saved
# 533 saved
# 534 saved
# 535 saved
# 536 saved
# 537 saved
# 538 saved
# 539 saved
# 540 saved
# 541 saved
# 542 saved
# 543 saved
# 544 saved
# 545 saved
# 546 saved
# 547 saved
# 548 saved
# 549 saved
# 550 saved
# 551 saved
# 552 saved
# 553 saved
# 554 saved
# 555 saved
# 556 saved
# 557 saved
# 558 saved
# 559 saved
# 560 saved
# 561 saved
# 562 saved
# 563 saved
# 564 saved
# 565 saved
# 566 saved
# 567 saved
# 568 saved
# 569 saved
# 570 saved
# 571 saved
# 572 saved
# 573 saved
# 574 saved
# 575 saved
# 576 saved
# 577 saved
# 578 saved
# 579 saved
# 580 saved
# 581 saved
# 582 saved
# 583 saved
# 584 saved
# 585 saved
# 586 saved
# 587 saved
# 588 saved
# 589 saved
# 590 saved
# 591 saved
# 592 saved
# 593 saved
# 594 saved
# 595 saved
# 596 saved
# 597 saved
# 598 saved
# 599 saved
# 600 saved
# 601 saved
# 602 saved
# 603 saved
# 604 saved
# 605 saved
# 606 saved
# 607 saved
# 608 saved
# 609 saved
# 610 saved
# 611 saved
# 612 saved
# 613 saved
# 614 saved
# 615 saved
# 616 saved
# 617 saved
# 618 saved
# 619 saved
# 620 saved
# 621 saved
# 622 saved
# 623 saved
# 624 saved
# 625 saved
# 626 saved
# 627 saved
# 628 saved
# 629 saved
# 630 saved
# 631 saved
