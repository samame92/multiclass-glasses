# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

datagen = ImageDataGenerator(
        rotation_range=30,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.1,
        zoom_range=0.1,
        horizontal_flip=True,
        fill_mode='nearest')

# %%
import os

def files(path):  
    for file in os.listdir(path):
        if os.path.isfile(os.path.join(path, file)):
            yield file

for name in files("C:/Users/Santiago/Desktop/Fraud Detecion"):  
    print (name)
# Out:
# glasses_0.jpg
# glasses_1.jpg
# glasses_10.jpg
# glasses_100.jpg
# glasses_101.jpg
# glasses_102.jpg
# glasses_11.jpg
# glasses_110.jpg
# glasses_111.jpg
# glasses_113.jpg
# glasses_12.jpg
# glasses_122.jpg
# glasses_125.jpg
# glasses_13.jpg
# glasses_133.jpg
# glasses_137.jpg
# glasses_138.jpg
# glasses_14.jpg
# glasses_144.jpg
# glasses_15.jpg
# glasses_150.jpg
# glasses_155.jpg
# glasses_16.jpg
# glasses_162.jpg
# glasses_166.jpg
# glasses_17.jpg
# glasses_174.jpg
# glasses_177.jpg
# glasses_18.jpg
# glasses_186.jpg
# glasses_188.jpg
# glasses_19.jpg
# glasses_198.jpg
# glasses_199.jpg
# glasses_2.jpg
# glasses_20.jpg
# glasses_21.jpg
# glasses_210.jpg
# glasses_211.jpg
# glasses_22.jpg
# glasses_221.jpg
# glasses_222.jpg
# glasses_224.jpg
# glasses_23.jpg
# glasses_233.jpg
# glasses_236.jpg
# glasses_24.jpg
# glasses_244.jpg
# glasses_248.jpg
# glasses_25.jpg
# glasses_255.jpg
# glasses_26.jpg
# glasses_260.jpg
# glasses_261.jpg
# glasses_266.jpg
# glasses_27.jpg
# ...

# %%
#prova = list({'0RB2140QMqt.jpg','0RB2140qt.jpg','0RB2180qt.jpg'})

# %%
for name in files("C:/Users/Santiago/Desktop/Fraud Detecion"):    
    img = load_img('C:/Users/Santiago/Desktop/Fraud Detecion/'+name)  # this is a PIL image
    x = img_to_array(img)  # this is a Numpy array with shape (3, 150, 150)
    x = x.reshape((1,) + x.shape)  # this is a Numpy array with shape (1, 3, 150, 150)

    # the .flow() command below generates batches of randomly transformed images
    # and saves the results to the `preview/` directory
    i = 0
    for batch in datagen.flow(x, batch_size=1,
                              save_to_dir='Generated2', save_prefix='prueba', save_format='jpeg'):
        i += 1
        if i > 20:  #Number of images generated
            break  # otherwise the generator would loop indefinitely
